# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import csv
from datetime import datetime
import timeit

# %matplotlib inline
matplotlib.style.use('ggplot')

# %% [markdown]
# # Project plan
# ### 1. What can we learn just from the time series
# * Try low pass filters
# * Look for periodicity using frequency domain
#
# ### 2. Other variables
# * Bivariate regressions
# * Outliers
#
# # Questions
# * Why many bivaraite plots appear banded? E.g. humidity against temperature.
# * Hook-shape in user counts. Times where there are many casual riders but not too many riders, or vice versa.
#     * Workday / weekend.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import csv
from datetime import datetime
import timeit

def readData_noParse():
    fileIn = "../data/train.csv"
    train = pd.read_csv(fileIn)
    columns = list(train.columns)
    columns[-1] = 'count_tot'
    train.columns = columns
    return train
def readData_parseIn():
    fileIn = "../data/train.csv"
    train = pd.read_csv(fileIn, parse_dates = [u'datetime'])
    columns = list(train.columns)
    columns[-1] = 'count_tot'
    train.columns = columns
    return train
def readData_parseOut():
    fileIn = "../data/train.csv"
    train = pd.read_csv(fileIn)
    train.datetime = train['datetime'].apply(lambda d: datetime.strptime(d, '%Y-%m-%d %H:%M:%S'))
    columns = list(train.columns)
    columns[-1] = 'count_tot'
    train.columns = columns
    return train

print timeit.repeat(readData_parseIn, repeat = 3, number = 10)
print timeit.repeat(readData_noParse, repeat = 3, number = 10)
print timeit.repeat(readData_parseOut, repeat = 3, number = 10)

# %%
# %timeit readData_parseIn()
# Out:
# 10 loops, best of 3: 22.6 ms per loop

# %%
# %timeit readData_parseOut()
# Out:
# 1 loops, best of 3: 174 ms per loop

# %%
# %timeit readData_parseIn()
# Out:
# 10 loops, best of 3: 21.3 ms per loop

# %%
print timeit.repeat(readData_parseIn, repeat = 3, number = 10)
print timeit.repeat(readData_noParse, repeat = 3, number = 10)
print timeit.repeat(readData_parseOut, repeat = 3, number = 10)
# Out:
# [0.36812806129455566, 0.22209405899047852, 0.22380495071411133]
# [0.16553187370300293, 0.17763209342956543, 0.19793105125427246]
# [1.8787360191345215, 1.7615540027618408, 1.7162649631500244]

# %%
#pd.read_csv?
train = readData_noParse()
type(train.datetime[0])

a = train['datetime'].apply(lambda d: datetime.strptime(d, '%Y-%m-%d %H:%M:%S'))

# %%
print type(a[0])
train.iloc[0:800].plot(x = 'datetime', y = 'count', kind = 'line', figsize = (16, 5), lw = 0.3)
# Out:
# <class 'pandas.tslib.Timestamp'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-f5b93e838393> in <module>()
#       1 print type(a[0])
# ----> 2 train.iloc[0:800].plot(x = 'datetime', y = 'count', kind = 'line', figsize = (16, 5), lw = 0.3)
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2451                  yerr=yerr, xerr=xerr,
#    2452                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2453                  **kwds)
#    2454
#    2455
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2277                 label = x if x is not None else data.index.name
#    2278                 label = kwds.pop('label', label)
# -> 2279                 series = data[y]
#    2280                 series.index.name = label
#    2281
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1741             return self._getitem_multilevel(key)
#    1742         else:
# -> 1743             return self._getitem_column(key)
#    1744
#    1745     def _getitem_column(self, key):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1748         # get column
#    1749         if self.columns.is_unique:
# -> 1750             return self._get_item_cache(key)
#    1751
#    1752         # duplicate columns & possible reduce dimensionaility
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1056         res = cache.get(item)
#    1057         if res is None:
# -> 1058             values = self._data.get(item)
#    1059             res = self._box_item_values(item, values)
#    1060             cache[item] = res
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2804
#    2805             if not isnull(item):
# -> 2806                 loc = self.items.get_loc(item)
#    2807             else:
#    2808                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1383         loc : int if unique index, possibly slice or mask if not
#    1384         """
# -> 1385         return self._engine.get_loc(_values_from_object(key))
#    1386
#    1387     def get_value(self, series, key):
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3795)()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3675)()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12299)()
#
# /Users/petervarshavsky/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12250)()
#
# KeyError: 'count'

# %% [markdown]
# ###### Correlations

# %%
print np.round(train.corr(), 2)
train.hist(figsize = (9,9))
plt.show()
# Out:
#             season  holiday  workingday  weather  temp  atemp  humidity  \
# season        1.00     0.03       -0.01     0.01  0.26   0.26      0.19
# holiday       0.03     1.00       -0.25    -0.01  0.00  -0.01      0.00
# workingday   -0.01    -0.25        1.00     0.03  0.03   0.02     -0.01
# weather       0.01    -0.01        0.03     1.00 -0.06  -0.06      0.41
# temp          0.26     0.00        0.03    -0.06  1.00   0.98     -0.06
# atemp         0.26    -0.01        0.02    -0.06  0.98   1.00     -0.04
# humidity      0.19     0.00       -0.01     0.41 -0.06  -0.04      1.00
# windspeed    -0.15     0.01        0.01     0.01 -0.02  -0.06     -0.32
# casual        0.10     0.04       -0.32    -0.14  0.47   0.46     -0.35
# registered    0.16    -0.02        0.12    -0.11  0.32   0.31     -0.27
# count         0.16    -0.01        0.01    -0.13  0.39   0.39     -0.32
#
#             windspeed  casual  registered  count
# season          -0.15    0.10        0.16   0.16
# holiday          0.01    0.04       -0.02  -0.01
# workingday       0.01   -0.32        0.12   0.01
# weather          0.01   -0.14       -0.11  -0.13
# temp            -0.02    0.47        0.32   0.39
# atemp           -0.06    0.46        0.31   0.39
# humidity        -0.32   -0.35       -0.27  -0.32
# windspeed        1.00    0.09        0.09   0.10
# casual           0.09    1.00        0.50   0.69
# registered       0.09    0.50        1.00   0.97
# count            0.10    0.69        0.97   1.00

# %%
noTimeColumns = train.columns[1:]
pd.scatter_matrix(train[noTimeColumns], figsize = (25, 25))
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8, 8))
plt.plot(train.humidity, train.temp, 'ro')
fig.suptitle("Humidity and air temperature")
ax.set_ylabel("Temperature")
ax.set_xlabel("Humidity")
ax.set_xlim((-5, 105))
plt.show()

# %%
fig, ax = plt.subplots(figsize = (8, 8))

ax.plot(train.casual[train.workingday == 1],
        np.log(train.count_tot[train.workingday == 1]), marker = 'o', ls = 'None', alpha = 0.5)
#ax.plot(train.casual[train.workingday == 0], train.count_tot[train.workingday == 0], marker = 'o', ls = 'None', alpha = 0.5)

plt.show()

# %%
train.casual.shape
# Out:
# (10886,)

# %%
train.count_tot.shape
# Out:
# (10886,)

# %%
train.columns
# Out:
# Index([u'datetime', u'season', u'holiday', u'workingday', u'weather', u'temp', u'atemp', u'humidity', u'windspeed', u'casual', u'registered', u'count_tot'], dtype='object')

# %%
train.head(24)
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5   2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6   2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7   2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8   2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9   2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 10  2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# 11  2011-01-01 11:00:00       1        0           0        1  14.76  16.665
# 12  2011-01-01 12:00:00       1        0           0        1  17.22  21.210
# 13  2011-01-01 13:00:00       1        0           0        2  18.86  22.725
# 14  2011-01-01 14:00:00       1        0           0        2  18.86  22.725
# 15  2011-01-01 15:00:00       1        0           0        2  18.04  21.970
# 16  2011-01-01 16:00:00       1        0           0        2  17.22  21.210
# 17  2011-01-01 17:00:00       1        0           0        2  18.04  21.970
# 18  2011-01-01 18:00:00       1        0           0        3  17.22  21.210
# 19  2011-01-01 19:00:00       1        0           0        3  17.22  21.210
# 20  2011-01-01 20:00:00       1        0           0        2  16.40  20.455
# 21  2011-01-01 21:00:00       1        0           0        2  16.40  20.455
# 22  2011-01-01 22:00:00       1        0           0        2  16.40  20.455
# 23  2011-01-01 23:00:00       1        0           0        2  18.86  22.725
#
#     humidity  windspeed  casual  registered  count_tot
# 0         81     0.0000       3          13         16
# 1         80     0.0000       8          32         40
# 2         80     0.0000       5          27         32
# 3         75     0.0000       3          10         13
# 4         75     0.0000       0           1          1
# 5         75     6.0032       0           1          1
# 6         80     0.0000       2           0          2
# 7         86     0.0000       1           2          3
# 8         75     0.0000       1           7          8
# 9         76     0.0000       8           6         14
# 10        76    16.9979      12          24         36
# 11        81    19.0012      26          30         56
# 12        77    19.0012      29          55         84
# 13        72    19.9995      47          47         94
# 14        72    19.0012      35          71        106
# 15        77    19.9995      40          70        110
# 16        82    19.9995      41          52         93
# 17        82    19.0012      15          52         67
# 18        88    16.9979       9          26         35
# 19        88    16.9979       6          31         37
# 20        87    16.9979      11          25         36
# 21        87    12.9980       3          31         34
# 22        94    15.0013      11          17         28
# 23        88    19.9995      15          24         39
