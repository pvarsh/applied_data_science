# %% [markdown]
# # Applied Data Science: Lab 1. Peter Varshavsky

# %% [markdown]
# ### Setting up

# %%
# %reset

### imports
import math
import numpy as np
import scipy as sp
import pandas as pd
from matplotlib import pyplot as plt
import statsmodels.api as sm
import patsy
import re
import matplotlib.pylab as pylab

### matplotlib settings
pylab.rcParams['figure.figsize'] = 16, 12  # that's default image size for this interactive session
# %matplotlib inline

### functions

### read file
filepath = "/Users/petervarshavsky/Documents/Git_NYU/applied_data_science/lab-1/data/"
traff_file = filepath + "trafficking_data.csv"
traff = pd.read_csv(traff_file)

### clean column names
colNames = traff.columns.values.tolist()
colNames = [col.lower() for col in colNames]
colNames = [re.sub(' ', '_', col) for col in colNames]
colNames[7] = "percent_fem_educ"
traff.columns = colNames

### clean country names
cNames = {country: country.title() for country in traff.country}
cNames['United Arab Emirate'] = 'United Arab Emirates'
cNames['Viet Nam'] = 'Vietnam'
traff.country = [cNames[c] for c in traff.country]

### total victims
traff['total_victims'] = traff.child_victims + traff.adult_victims
columns = traff.columns.values.tolist()
columns_reorder = ['country', 'year', 
                   'persons_prosecuted', 'adult_victims', 
                   'child_victims', 'total_victims', 'gdp',
                   'policy_index', 'percent_fem_educ',
                   'life_expectancy']
traff = traff[columns_reorder]

### checking columns for missing data

print "Missing values in columns:\n",  traff.isnull().sum()[traff.isnull().sum() > 0]
print traff.shape

### removing missing values
traff = traff[traff.child_victims.notnull()]
print traff.shape
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Missing values in columns:
# child_victims    2
# total_victims    2
# dtype: int64
# (158, 10)
# (156, 10)

# %% [markdown]
# ### Problem 1: Checking predictive power

# %% [markdown]
# ###### Modeling adult_victims

# %%
### All predictors including country names (obviously a bad model)
# all_columns = traff.columns.values.tolist()
# y, X = patsy.dmatrices('adult_victims ~ country + year + policy_index + percent_fem_educ + life_expectancy',
#                        data = traff,
#                        return_type='dataframe')

# everything_bagel = sm.OLS(y, X)
# results_everything  = everything_bagel.fit()
# print results_everything.summary()

### All predictors excluding country names
y, X = patsy.dmatrices('adult_victims ~ gdp + year + policy_index + percent_fem_educ + life_expectancy + persons_prosecuted',
                        data = traff,
                        return_type='dataframe')
main_effects_fit = sm.OLS(y, X).fit()
print main_effects_fit.summary()

### Comparing all bivariates
#print traff.columns.values
cols = ['year', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy', 'persons_prosecuted']
bivariate_dmatrices = [patsy.dmatrices('adult_victims ~ ' + col,
                                       data = traff,
                                       return_type = 'dataframe') for col in cols]
bivariate_fits = [sm.OLS(dmatrix[0], dmatrix[1]).fit() for dmatrix in bivariate_dmatrices]

for fit in bivariate_fits:
    print '####################'
    print '####################'
    print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.007
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.392
# Time:                        21:48:29   Log-Likelihood:                -1263.8
# No. Observations:                 156   AIC:                             2536.
# Df Residuals:                     152   BIC:                             2548.
# Df Model:                           3
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              0.0051      0.006      0.882      0.379        -0.006     0.017
# gdp                 4.388e-12   3.15e-11      0.139      0.889     -5.79e-11  6.67e-11
# year                   2.6768      2.043      1.311      0.192        -1.359     6.712
# policy_index          15.0845     32.018      0.471      0.638       -48.174    78.343
# percent_fem_educ    -112.3274     83.173     -1.351      0.179      -276.652    51.997
# life_expectancy        2.8525      9.028      0.316      0.752       -14.984    20.689
# persons_prosecuted    -0.0160      0.019     -0.841      0.402        -0.054     0.022
# ==============================================================================
# Omnibus:                      190.471   Durbin-Watson:                   0.801
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5184.949
# Skew:                           4.930   Prob(JB):                         0.00
# Kurtosis:                      29.466   Cond. No.                     3.89e+15
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.89e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.2608
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.610
# Time:                        21:48:29   Log-Likelihood:                -1265.2
# No. Observations:                 156   AIC:                             2534.
# Df Residuals:                     154   BIC:                             2541.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -4.998e+04   9.84e+04     -0.508      0.612     -2.44e+05  1.44e+05
# year          25.0619     49.075      0.511      0.610       -71.885   122.009
# ==============================================================================
# Omnibus:                      197.881   Durbin-Watson:                   0.787
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6008.240
# Skew:                           5.203   Prob(JB):                         0.00
# Kurtosis:                      31.567   Cond. No.                     3.04e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.04e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                       inf
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):                nan
# Time:                        21:48:29   Log-Likelihood:                -1265.3
# No. Observations:                 156   AIC:                             2533.
# Df Residuals:                     155   BIC:                             2536.
# Df Model:                           0
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    264.5074     67.374      3.926      0.000       131.417   397.598
# gdp         9.491e-12   2.73e-11      0.348      0.728     -4.44e-11  6.33e-11
# ==============================================================================
# Omnibus:                      197.933   Durbin-Watson:                   0.787
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6025.962
# Skew:                           5.203   Prob(JB):                         0.00
# Kurtosis:                      31.614   Cond. No.                     2.57e+12
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.57e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.6961
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.405
# Time:                        21:48:29   Log-Likelihood:                -1265.0
# No. Observations:                 156   AIC:                             2534.
# Df Residuals:                     154   BIC:                             2540.
# Df Model:                           1
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       48.6099    274.343      0.177      0.860      -493.352   590.572
# policy_index    22.7520     27.270      0.834      0.405       -31.119    76.623
# ==============================================================================
# Omnibus:                      196.817   Durbin-Watson:                   0.789
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5898.895
# Skew:                           5.161   Prob(JB):                         0.00
# Kurtosis:                      31.301   Cond. No.                         43.0
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.523
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.219
# Time:                        21:48:29   Log-Likelihood:                -1264.6
# No. Observations:                 156   AIC:                             2533.
# Df Residuals:                     154   BIC:                             2539.
# Df Model:                           1
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         5041.7717   3865.893      1.304      0.194     -2595.255  1.27e+04
# percent_fem_educ   -98.7961     80.047     -1.234      0.219      -256.927    59.335
# ==============================================================================
# Omnibus:                      192.883   Durbin-Watson:                   0.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5448.330
# Skew:                           5.017   Prob(JB):                         0.00
# Kurtosis:                      30.157   Cond. No.                     2.89e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.4072
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.524
# Time:                        21:48:29   Log-Likelihood:                -1265.1
# No. Observations:                 156   AIC:                             2534.
# Df Residuals:                     154   BIC:                             2540.
# Df Model:                           1
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept         -72.4540    542.143     -0.134      0.894     -1143.450   998.542
# life_expectancy     5.2317      8.198      0.638      0.524       -10.964    21.427
# ==============================================================================
# Omnibus:                      196.131   Durbin-Watson:                   0.775
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5818.792
# Skew:                           5.136   Prob(JB):                         0.00
# Kurtosis:                      31.101   Cond. No.                         553.
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          adult_victims   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.3688
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.545
# Time:                        21:48:29   Log-Likelihood:                -1265.1
# No. Observations:                 156   AIC:                             2534.
# Df Residuals:                     154   BIC:                             2540.
# Df Model:                           1
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept            277.8449     65.843      4.220      0.000       147.773   407.917
# persons_prosecuted    -0.0114      0.019     -0.607      0.545        -0.048     0.026
# ==============================================================================
# Omnibus:                      197.986   Durbin-Watson:                   0.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6041.998
# Skew:                           5.204   Prob(JB):                         0.00
# Kurtosis:                      31.657   Cond. No.                     3.57e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Modeling child_victims

# %%
### All predictors excluding country names
y, X = patsy.dmatrices('child_victims ~ gdp + year + policy_index + percent_fem_educ + life_expectancy + persons_prosecuted',
                        data = traff,
                        return_type='dataframe')
main_effects_fit = sm.OLS(y, X).fit()
print main_effects_fit.summary()

### Comparing all bivariates
#print traff.columns.values
cols = ['year', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy', 'persons_prosecuted']
bivariate_dmatrices = [patsy.dmatrices('child_victims ~ ' + col,
                                       data = traff,
                                       return_type = 'dataframe') for col in cols]
bivariate_fits = [sm.OLS(dmatrix[0], dmatrix[1]).fit() for dmatrix in bivariate_dmatrices]

for fit in bivariate_fits:
    print '####################'
    print '####################'
    print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.109
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     6.196
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):           0.000534
# Time:                        21:48:29   Log-Likelihood:                -912.05
# No. Observations:                 156   AIC:                             1832.
# Df Residuals:                     152   BIC:                             1844.
# Df Model:                           3
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept              0.0013      0.001      2.157      0.033         0.000     0.003
# gdp                -2.763e-13   3.31e-12     -0.084      0.934     -6.81e-12  6.25e-12
# year                   0.7506      0.214      3.504      0.001         0.327     1.174
# policy_index           3.7754      3.358      1.124      0.263        -2.860    10.411
# percent_fem_educ     -28.0144      8.724     -3.211      0.002       -45.250   -10.779
# life_expectancy       -2.2968      0.947     -2.426      0.016        -4.168    -0.426
# persons_prosecuted    -0.0034      0.002     -1.678      0.095        -0.007     0.001
# ==============================================================================
# Omnibus:                      154.377   Durbin-Watson:                   0.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2602.781
# Skew:                           3.704   Prob(JB):                         0.00
# Kurtosis:                      21.589   Cond. No.                     3.89e+15
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.89e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7935
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.374
# Time:                        21:48:29   Log-Likelihood:                -920.64
# No. Observations:                 156   AIC:                             1845.
# Df Residuals:                     154   BIC:                             1851.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept  -9591.6834   1.08e+04     -0.887      0.376     -3.09e+04  1.18e+04
# year           4.8018      5.390      0.891      0.374        -5.847    15.451
# ==============================================================================
# Omnibus:                      150.582   Durbin-Watson:                   0.826
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1985.289
# Skew:                           3.704   Prob(JB):                         0.00
# Kurtosis:                      18.829   Cond. No.                     3.04e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.04e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                       inf
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):                nan
# Time:                        21:48:29   Log-Likelihood:                -920.76
# No. Observations:                 156   AIC:                             1844.
# Df Residuals:                     155   BIC:                             1847.
# Df Model:                           0
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     37.7160      7.403      5.095      0.000        23.093    52.339
# gdp        -2.247e-12      3e-12     -0.750      0.454     -8.16e-12  3.67e-12
# ==============================================================================
# Omnibus:                      148.876   Durbin-Watson:                   0.833
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1905.387
# Skew:                           3.656   Prob(JB):                         0.00
# Kurtosis:                      18.482   Cond. No.                     2.57e+12
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.57e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.2050
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.651
# Time:                        21:48:29   Log-Likelihood:                -920.94
# No. Observations:                 156   AIC:                             1846.
# Df Residuals:                     154   BIC:                             1852.
# Df Model:                           1
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept       22.8705     30.234      0.756      0.451       -36.857    82.598
# policy_index     1.3608      3.005      0.453      0.651        -4.576     7.298
# ==============================================================================
# Omnibus:                      149.207   Durbin-Watson:                   0.823
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1908.189
# Skew:                           3.669   Prob(JB):                         0.00
# Kurtosis:                      18.483   Cond. No.                         43.0
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     9.467
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):            0.00248
# Time:                        21:48:29   Log-Likelihood:                -916.39
# No. Observations:                 156   AIC:                             1837.
# Df Residuals:                     154   BIC:                             1843.
# Df Model:                           1
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         1312.6005    414.902      3.164      0.002       492.966  2132.235
# percent_fem_educ   -26.4332      8.591     -3.077      0.002       -43.404    -9.462
# ==============================================================================
# Omnibus:                      146.341   Durbin-Watson:                   0.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1958.874
# Skew:                           3.531   Prob(JB):                         0.00
# Kurtosis:                      18.859   Cond. No.                     2.89e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     4.339
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):             0.0389
# Time:                        21:48:29   Log-Likelihood:                -918.88
# No. Observations:                 156   AIC:                             1842.
# Df Residuals:                     154   BIC:                             1848.
# Df Model:                           1
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept         157.9966     58.907      2.682      0.008        41.626   274.367
# life_expectancy    -1.8555      0.891     -2.083      0.039        -3.615    -0.096
# ==============================================================================
# Omnibus:                      154.212   Durbin-Watson:                   0.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2307.365
# Skew:                           3.768   Prob(JB):                         0.00
# Kurtosis:                      20.268   Cond. No.                         553.
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.6810
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.411
# Time:                        21:48:29   Log-Likelihood:                -920.70
# No. Observations:                 156   AIC:                             1845.
# Df Residuals:                     154   BIC:                             1852.
# Df Model:                           1
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept             37.1916      7.237      5.139      0.000        22.894    51.489
# persons_prosecuted    -0.0017      0.002     -0.825      0.411        -0.006     0.002
# ==============================================================================
# Omnibus:                      149.366   Durbin-Watson:                   0.831
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1923.934
# Skew:                           3.671   Prob(JB):                         0.00
# Kurtosis:                      18.559   Cond. No.                     3.57e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ###### Modeling persons_prosecuted

# %%
### All predictors excluding country names
y, X = patsy.dmatrices('persons_prosecuted ~ gdp + year + policy_index + percent_fem_educ + life_expectancy',
                        data = traff,
                        return_type='dataframe')
main_effects_fit = sm.OLS(y, X).fit()
print main_effects_fit.summary()

### Comparing all bivariates
#print traff.columns.values
cols = ['year', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy']
bivariate_dmatrices = [patsy.dmatrices('persons_prosecuted ~ ' + col,
                                       data = traff,
                                       return_type = 'dataframe') for col in cols]
bivariate_fits = [sm.OLS(dmatrix[0], dmatrix[1]).fit() for dmatrix in bivariate_dmatrices]

for fit in bivariate_fits:
    print '####################'
    print '####################'
    print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     persons_prosecuted   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     3.401
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):             0.0359
# Time:                        21:48:30   Log-Likelihood:                -1489.7
# No. Observations:                 156   AIC:                             2985.
# Df Residuals:                     153   BIC:                             2995.
# Df Model:                           2
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            0.0477      0.027      1.796      0.075        -0.005     0.100
# gdp               7.089e-11   1.34e-10      0.531      0.596     -1.93e-10  3.35e-10
# year                20.5959      8.500      2.423      0.017         3.803    37.388
# policy_index        47.6318    135.723      0.351      0.726      -220.501   315.764
# percent_fem_educ  -795.7608    346.788     -2.295      0.023     -1480.871  -110.650
# life_expectancy    -42.3887     38.129     -1.112      0.268      -117.717    32.939
# ==============================================================================
# Omnibus:                      214.526   Durbin-Watson:                   0.543
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8663.042
# Skew:                           5.824   Prob(JB):                         0.00
# Kurtosis:                      37.599   Cond. No.                     3.89e+15
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.89e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     persons_prosecuted   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.3277
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.568
# Time:                        21:48:30   Log-Likelihood:                -1492.9
# No. Observations:                 156   AIC:                             2990.
# Df Residuals:                     154   BIC:                             2996.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   2.431e+05   4.24e+05      0.574      0.567     -5.94e+05  1.08e+06
# year        -120.9331    211.248     -0.572      0.568      -538.251   296.385
# ==============================================================================
# Omnibus:                      222.564   Durbin-Watson:                   0.539
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9881.384
# Skew:                           6.173   Prob(JB):                         0.00
# Kurtosis:                      39.984   Cond. No.                     3.04e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.04e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     persons_prosecuted   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       inf
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):                nan
# Time:                        21:48:30   Log-Likelihood:                -1493.1
# No. Observations:                 156   AIC:                             2988.
# Df Residuals:                     155   BIC:                             2991.
# Df Model:                           0
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    590.8477    290.181      2.036      0.043        17.628  1164.068
# gdp         1.431e-11   1.17e-10      0.122      0.903     -2.18e-10  2.46e-10
# ==============================================================================
# Omnibus:                      222.542   Durbin-Watson:                   0.534
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9826.518
# Skew:                           6.175   Prob(JB):                         0.00
# Kurtosis:                      39.868   Cond. No.                     2.57e+12
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.57e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     persons_prosecuted   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.1583
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.691
# Time:                        21:48:30   Log-Likelihood:                -1493.0
# No. Observations:                 156   AIC:                             2990.
# Df Residuals:                     154   BIC:                             2996.
# Df Model:                           1
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept      143.2412   1183.248      0.121      0.904     -2194.251  2480.734
# policy_index    46.7930    117.614      0.398      0.691      -185.553   279.139
# ==============================================================================
# Omnibus:                      222.439   Durbin-Watson:                   0.534
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9815.788
# Skew:                           6.170   Prob(JB):                         0.00
# Kurtosis:                      39.849   Cond. No.                         43.0
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     persons_prosecuted   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     5.479
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):             0.0205
# Time:                        21:48:30   Log-Likelihood:                -1490.4
# No. Observations:                 156   AIC:                             2985.
# Df Residuals:                     154   BIC:                             2991.
# Df Model:                           1
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         3.907e+04   1.64e+04      2.377      0.019      6599.675  7.15e+04
# percent_fem_educ  -796.6642    340.340     -2.341      0.021     -1469.003  -124.326
# ==============================================================================
# Omnibus:                      216.438   Durbin-Watson:                   0.542
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8951.183
# Skew:                           5.905   Prob(JB):                         0.00
# Kurtosis:                      38.180   Cond. No.                     2.89e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 2.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     persons_prosecuted   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.8331
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.363
# Time:                        21:48:30   Log-Likelihood:                -1492.7
# No. Observations:                 156   AIC:                             2989.
# Df Residuals:                     154   BIC:                             2995.
# Df Model:                           1
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept        2713.0017   2330.992      1.164      0.246     -1891.846  7317.849
# life_expectancy   -32.1737     35.249     -0.913      0.363      -101.808    37.461
# ==============================================================================
# Omnibus:                      221.352   Durbin-Watson:                   0.537
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9619.934
# Skew:                           6.124   Prob(JB):                         0.00
# Kurtosis:                      39.469   Cond. No.                         553.
# ==============================================================================

# %% [markdown]
# ### Problem 2. Removing outliers

# %%
print traff.columns.values.tolist()
cols = ['persons_prosecuted', 'adult_victims', 'child_victims', 'total_victims', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy']

print traff[['country', 'year', 'persons_prosecuted']][traff.persons_prosecuted > 15000]
print traff[['country', 'year', 'child_victims']][traff.child_victims > 300]
print traff[['country', 'year', 'gdp']][traff.gdp > 0.3*1e13]
print traff[['country', 'year', 'policy_index']][traff.policy_index < 2]


### plotting histograms
pylab.rcParams['figure.figsize'] = (16, 16)
plt.figure(1)
plot_count = 1
for col in cols:
    plt.subplot(4, 2, plot_count)
    plt.hist(traff[col], bins=15, color='orange')
    plt.xlabel(col)
    plot_count += 1
    
plt.show()



# # for col in cols:
# #     plt.hist(np.log(traff[col]), bins=15, color='cyan')
# #     plt.xlabel('log ' + col)
# #     plt.show()

### persons_prosecuted outliers
print traff.country[traff.persons_prosecuted > 5000]
traffOutRem = traff[traff.persons_prosecuted < 5000]
print traff.shape
print traffOutRem.shape

### gdp outliers
#traffOutRem = traffOutRem[traffOutRem.gdp < 0.3*1e13]


# ### All predictors excluding country names
# y, X = patsy.dmatrices('adult_victims ~ gdp + year + policy_index + percent_fem_educ + life_expectancy',
#                         data = traffOutRem,
#                         return_type='dataframe')
# main_effects_fit = sm.OLS(y, X).fit()
# print main_effects_fit.summary()

# y, X = patsy.dmatrices('child_victims ~ gdp + year + policy_index + percent_fem_educ + life_expectancy',
#                         data = traffOutRem,
#                         return_type='dataframe')
# main_effects_fit = sm.OLS(y, X).fit()
# print main_effects_fit.summary()

# y, X = patsy.dmatrices('total_victims ~ gdp + year + policy_index + percent_fem_educ + life_expectancy',
#                         data = traffOutRem,
#                         return_type='dataframe')
# main_effects_fit = sm.OLS(y, X).fit()
# print main_effects_fit.summary()
# Out:
# ['country', 'year', 'persons_prosecuted', 'adult_victims', 'child_victims', 'total_victims', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy']
#    country  year  persons_prosecuted
# 53   India  2003               17870
# 54   India  2004               20390
# 55   India  2005               23053
# 56   India  2006               25844
#       country  year  child_victims
# 27   Cambodia  2003            336
# 28   Cambodia  2004            433
# 29   Cambodia  2005            303
# 129  Thailand  2005            614
# 130  Thailand  2006            416
#     country  year           gdp
# 66    Japan  2003  4.302939e+12
# 67    Japan  2004  4.655803e+12
# 68    Japan  2005  4.571867e+12
# 69    Japan  2006  4.356750e+12
# 144     Usa  2003  1.151220e+13
# 145     Usa  2004  1.227700e+13
# 146     Usa  2005  1.309540e+13
# 147     Usa  2006  1.385790e+13
# 148     Usa  2007  1.448030e+13
#      country  year  policy_index
# 91  Mongolia  2003             0
# 53    India
# 54    India
# 55    India
# 56    India
# Name: country, dtype: object
# (156, 10)
# (152, 10)

# %% [markdown]
# ###### Looking at child_victims main effects model.

# %%
y, X = patsy.dmatrices('child_victims ~ percent_fem_educ + life_expectancy + persons_prosecuted',
                        data = traffOutRem,
                        return_type='dataframe')
main_effects_fit = sm.OLS(y, X).fit()
print main_effects_fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          child_victims   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     5.528
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):            0.00126
# Time:                        21:48:32   Log-Likelihood:                -891.00
# No. Observations:                 152   AIC:                             1790.
# Df Residuals:                     148   BIC:                             1802.
# Df Model:                           3
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# Intercept           1606.9829    429.073      3.745      0.000       759.082  2454.884
# percent_fem_educ     -29.8896      8.809     -3.393      0.001       -47.298   -12.481
# life_expectancy       -1.8483      0.875     -2.111      0.036        -3.578    -0.118
# persons_prosecuted    -0.0981      0.112     -0.880      0.380        -0.319     0.122
# ==============================================================================
# Omnibus:                      147.786   Durbin-Watson:                   0.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2293.073
# Skew:                           3.613   Prob(JB):                         0.00
# Kurtosis:                      20.603   Cond. No.                     6.09e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 6.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Problem 3. Log transform

# %% [markdown]
# ###### Log transofrm and -inf substitution

# %%
### log transform
traffNumeric = traffOutRem._get_numeric_data()
traffNumeric = np.log(traffNumeric)
### change -inf to 1
traffNumeric[traffNumeric == -np.inf] = 1
### change names
names = traffNumeric.columns.values.tolist()
for i in range(len(names)):
    names[i] = 'log_' + names[i]
traffNumeric.columns = names
print traffNumeric.head()
#traffOutRem = pd.concat([traffOutRem, traffNumeric], axis = 0)
traffOutRem = pd.merge(traffOutRem, traffNumeric, how = 'inner', left_index = True, right_index = True)
print traffOutRem.head()
# Out:
#    log_year  log_persons_prosecuted  log_adult_victims  log_child_victims  \
# 0  7.603399                1.000000           3.401197                  1
# 1  7.603898                1.000000           4.143135                  1
# 2  7.604396                1.000000           4.369448                  1
# 3  7.602401                1.000000           0.693147                  1
# 4  7.602900                1.098612           3.496508                  1
#
#    log_total_victims    log_gdp  log_policy_index  log_percent_fem_educ  \
# 0           3.401197  26.130023          2.197225              3.888216
# 1           4.143135  26.301068          2.302585              3.887177
# 2           4.369448  26.521635          2.079442              3.887706
# 3           0.693147  21.755404          2.397895              3.881597
# 4           3.496508  21.997683          2.079442              3.878404
#
#    log_life_expectancy
# 0             4.290459
# 1             4.290459
# 2             4.290459
# 3             4.127134
# 4             4.127134
#      country  year  persons_prosecuted  adult_victims  child_victims  \
# 0  Argentina  2005                   0             30              0
# 1  Argentina  2006                   0             63              0
# 2  Argentina  2007                   0             79              0
# 3    Armenia  2003                   0              2              0
# 4    Armenia  2004                   3             33              0
#
#    total_victims           gdp  policy_index  percent_fem_educ  \
# 0             30  2.229076e+11             9          48.82373
# 1             63  2.644897e+11            10          48.77301
# 2             79  3.297615e+11             8          48.79879
# 3              2  2.807061e+09            11          48.50162
# 4             33  3.576615e+09             8          48.34700
#
#    life_expectancy  log_year  log_persons_prosecuted  log_adult_victims  \
# 0               73  7.603399                1.000000           3.401197
# 1               73  7.603898                1.000000           4.143135
# 2               73  7.604396                1.000000           4.369448
# 3               62  7.602401                1.000000           0.693147
# 4               62  7.602900                1.098612           3.496508
#
#    log_child_victims  log_total_victims    log_gdp  log_policy_index  \
# 0                  1           3.401197  26.130023          2.197225
# 1                  1           4.143135  26.301068          2.302585
# 2                  1           4.369448  26.521635          2.079442
# 3                  1           0.693147  21.755404          2.397895
# 4                  1           3.496508  21.997683          2.079442
#
#    log_percent_fem_educ  log_life_expectancy
# 0              3.888216             4.290459
# 1              3.887177             4.290459
# 2              3.887706             4.290459
# 3              3.881597             4.127134
# 4              3.878404             4.127134

# %%
y, X = patsy.dmatrices('log_child_victims ~ log_gdp + log_life_expectancy + log_percent_fem_educ + log_persons_prosecuted + log_policy_index', data = traffOutRem, return_type = 'dataframe')
log_fit = sm.OLS(y, X).fit()
print log_fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     4.200
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):            0.00135
# Time:                        21:48:33   Log-Likelihood:                -275.06
# No. Observations:                 152   AIC:                             562.1
# Df Residuals:                     146   BIC:                             580.3
# Df Model:                           5
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                 81.9845     29.518      2.777      0.006        23.648   140.321
# log_gdp                    0.0301      0.031      0.968      0.335        -0.031     0.092
# log_life_expectancy       -4.0978      1.116     -3.672      0.000        -6.303    -1.892
# log_percent_fem_educ     -16.7676      7.628     -2.198      0.030       -31.843    -1.693
# log_persons_prosecuted    -0.0351      0.086     -0.408      0.684        -0.205     0.135
# log_policy_index           0.7247      0.513      1.412      0.160        -0.290     1.739
# ==============================================================================
# Omnibus:                       19.328   Durbin-Watson:                   0.715
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.360
# Skew:                           0.958   Prob(JB):                     8.46e-06
# Kurtosis:                       3.124   Cond. No.                     6.26e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 6.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ###### Bivariate regressions for the log-transforms.

# %%
### Comparing all bivariates
#print traff.columns.values
cols = ['log_gdp', 'log_policy_index', 'log_percent_fem_educ', 'log_life_expectancy', 'log_persons_prosecuted']
bivariate_log_dmatrices = [patsy.dmatrices('log_child_victims ~ ' + col,
                                       data = traffOutRem,
                                       return_type = 'dataframe') for col in cols]
bivariate_log_fits = [sm.OLS(dmatrix[0], dmatrix[1]).fit() for dmatrix in bivariate_log_dmatrices]

for fit in bivariate_log_fits:
    print '####################'
    print '####################'
    print fit.summary()
# Out:
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.1425
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.706
# Time:                        21:48:33   Log-Likelihood:                -285.20
# No. Observations:                 152   AIC:                             574.4
# Df Residuals:                     150   BIC:                             580.4
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      1.8531      0.652      2.844      0.005         0.565     3.141
# log_gdp        0.0102      0.027      0.378      0.706        -0.043     0.063
# ==============================================================================
# Omnibus:                       23.593   Durbin-Watson:                   0.746
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.014
# Skew:                           1.105   Prob(JB):                     1.84e-07
# Kurtosis:                       2.888   Cond. No.                         122.
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.4042
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.526
# Time:                        21:48:33   Log-Likelihood:                -285.07
# No. Observations:                 152   AIC:                             574.1
# Df Residuals:                     150   BIC:                             580.2
# Df Model:                           1
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            1.3987      1.101      1.270      0.206        -0.778     3.575
# log_policy_index     0.3093      0.486      0.636      0.526        -0.652     1.271
# ==============================================================================
# Omnibus:                       23.439   Durbin-Watson:                   0.738
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.752
# Skew:                           1.100   Prob(JB):                     2.10e-07
# Kurtosis:                       2.879   Cond. No.                         23.1
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     6.648
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):             0.0109
# Time:                        21:48:33   Log-Likelihood:                -281.98
# No. Observations:                 152   AIC:                             568.0
# Df Residuals:                     150   BIC:                             574.0
# Df Model:                           1
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept               77.8564     29.383      2.650      0.009        19.798   135.915
# log_percent_fem_educ   -19.5384      7.578     -2.578      0.011       -34.511    -4.566
# ==============================================================================
# Omnibus:                       19.070   Durbin-Watson:                   0.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.106
# Skew:                           0.939   Prob(JB):                     9.61e-06
# Kurtosis:                       2.654   Cond. No.                         962.
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     10.08
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):            0.00182
# Time:                        21:48:33   Log-Likelihood:                -280.33
# No. Observations:                 152   AIC:                             564.7
# Df Residuals:                     150   BIC:                             570.7
# Df Model:                           1
# =======================================================================================
#                           coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------
# Intercept              15.3804      4.186      3.674      0.000         7.109    23.652
# log_life_expectancy    -3.1799      1.001     -3.175      0.002        -5.159    -1.201
# ==============================================================================
# Omnibus:                       21.528   Durbin-Watson:                   0.752
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.154
# Skew:                           1.035   Prob(JB):                     1.27e-06
# Kurtosis:                       3.043   Cond. No.                         148.
# ==============================================================================
# ####################
# ####################
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.1134
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):              0.737
# Time:                        21:48:33   Log-Likelihood:                -285.22
# No. Observations:                 152   AIC:                             574.4
# Df Residuals:                     150   BIC:                             580.5
# Df Model:                           1
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                  2.0174      0.262      7.698      0.000         1.500     2.535
# log_persons_prosecuted     0.0284      0.084      0.337      0.737        -0.138     0.195
# ==============================================================================
# Omnibus:                       23.632   Durbin-Watson:                   0.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.083
# Skew:                           1.106   Prob(JB):                     1.78e-07
# Kurtosis:                       2.888   Cond. No.                         6.83
# ==============================================================================

# %% [markdown]
# ###### Excluding gdp, policy_index

# %%
print traffOutRem.columns.values.tolist()
y, X = patsy.dmatrices('log_child_victims ~ log_life_expectancy + log_percent_fem_educ + year + log_gdp + policy_index', data = traffOutRem, return_type = 'dataframe')
log_fit = sm.OLS(y, X).fit()
print log_fit.summary()
# Out:
# ['country', 'year', 'persons_prosecuted', 'adult_victims', 'child_victims', 'total_victims', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy', 'log_year', 'log_persons_prosecuted', 'log_adult_victims', 'log_child_victims', 'log_total_victims', 'log_gdp', 'log_policy_index', 'log_percent_fem_educ', 'log_life_expectancy']
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.117
# Method:                 Least Squares   F-statistic:                     5.017
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):           0.000285
# Time:                        21:48:34   Log-Likelihood:                -273.22
# No. Observations:                 152   AIC:                             558.4
# Df Residuals:                     146   BIC:                             576.6
# Df Model:                           5
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept             -250.8386    189.982     -1.320      0.189      -626.308   124.631
# log_life_expectancy     -4.1082      1.110     -3.699      0.000        -6.303    -1.913
# log_percent_fem_educ   -17.4879      7.526     -2.324      0.022       -32.362    -2.614
# year                     0.1679      0.094      1.778      0.078        -0.019     0.355
# log_gdp                  0.0245      0.030      0.820      0.414        -0.035     0.084
# policy_index             0.0644      0.058      1.103      0.272        -0.051     0.180
# ==============================================================================
# Omnibus:                       18.569   Durbin-Watson:                   0.701
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.006
# Skew:                           0.927   Prob(JB):                     1.67e-05
# Kurtosis:                       3.188   Cond. No.                     3.15e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.15e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
### Reading internet penetration by country
print filepath
penetration_file = "internet-penetration-by-country-1.csv"
penetration = pd.read_csv(filepath + penetration_file, dtype = {'penetration ': np.float64}, na_values=['n/a', ' -   '])
penetration.columns = ['country', 'penetration']

traffOutRem = pd.merge(traffOutRem, penetration, how = 'inner', on = 'country')
print traffOutRem.head()
# Out:
# /Users/petervarshavsky/Documents/Git_NYU/applied_data_science/lab-1/data/
#      country  year  persons_prosecuted  adult_victims  child_victims  \
# 0  Argentina  2005                   0             30              0
# 1  Argentina  2006                   0             63              0
# 2  Argentina  2007                   0             79              0
# 3    Armenia  2003                   0              2              0
# 4    Armenia  2004                   3             33              0
#
#    total_victims           gdp  policy_index  percent_fem_educ  \
# 0             30  2.229076e+11             9          48.82373
# 1             63  2.644897e+11            10          48.77301
# 2             79  3.297615e+11             8          48.79879
# 3              2  2.807061e+09            11          48.50162
# 4             33  3.576615e+09             8          48.34700
#
#    life_expectancy  log_year  log_persons_prosecuted  log_adult_victims  \
# 0               73  7.603399                1.000000           3.401197
# 1               73  7.603898                1.000000           4.143135
# 2               73  7.604396                1.000000           4.369448
# 3               62  7.602401                1.000000           0.693147
# 4               62  7.602900                1.098612           3.496508
#
#    log_child_victims  log_total_victims    log_gdp  log_policy_index  \
# 0                  1           3.401197  26.130023          2.197225
# 1                  1           4.143135  26.301068          2.302585
# 2                  1           4.369448  26.521635          2.079442
# 3                  1           0.693147  21.755404          2.397895
# 4                  1           3.496508  21.997683          2.079442
#
#    log_percent_fem_educ  log_life_expectancy  penetration
# 0              3.888216             4.290459        0.750
# 1              3.887177             4.290459        0.750
# 2              3.887706             4.290459        0.750
# 3              3.881597             4.127134        0.588
# 4              3.878404             4.127134        0.588

# %% [markdown]
# ###### Adding internet penetration

# %%
traffOutRem.penetration = np.random.normal(0, 0.01, 122) + traffOutRem.penetration
# traffOutRem.head()

traffOutRem['log_penetration'] = np.log(traffOutRem.penetration)
#print traffOutRem.log_penetration

print traffOutRem.columns.values.tolist()
y, X = patsy.dmatrices('log_child_victims ~ log_penetration + log_life_expectancy + log_percent_fem_educ + year + log_gdp + policy_index', data = traffOutRem, return_type = 'dataframe')
log_fit = sm.OLS(y, X).fit()
print log_fit.summary()
# Out:
# ['country', 'year', 'persons_prosecuted', 'adult_victims', 'child_victims', 'total_victims', 'gdp', 'policy_index', 'percent_fem_educ', 'life_expectancy', 'log_year', 'log_persons_prosecuted', 'log_adult_victims', 'log_child_victims', 'log_total_victims', 'log_gdp', 'log_policy_index', 'log_percent_fem_educ', 'log_life_expectancy', 'penetration', 'log_penetration']
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     9.057
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):           4.18e-08
# Time:                        21:48:35   Log-Likelihood:                -207.02
# No. Observations:                 122   AIC:                             428.0
# Df Residuals:                     115   BIC:                             447.7
# Df Model:                           6
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept             -289.7350    194.553     -1.489      0.139      -675.108    95.638
# log_penetration         -1.6290      0.289     -5.634      0.000        -2.202    -1.056
# log_life_expectancy      1.9555      1.473      1.328      0.187        -0.961     4.872
# log_percent_fem_educ    -6.9809      8.784     -0.795      0.428       -24.381    10.419
# year                     0.1537      0.096      1.596      0.113        -0.037     0.344
# log_gdp                  0.0298      0.070      0.428      0.670        -0.108     0.168
# policy_index             0.0414      0.061      0.677      0.500        -0.080     0.163
# ==============================================================================
# Omnibus:                       22.491   Durbin-Watson:                   0.743
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.097
# Skew:                           1.122   Prob(JB):                     7.92e-07
# Kurtosis:                       3.702   Cond. No.                     3.17e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.17e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ###### Adding World Bank Gini (from Wikipedia)

# %%
print filepath
gini_file = "wbgini-by-country-1.csv"
gini = pd.read_csv(filepath + gini_file, dtype = {'gini': np.float64})

traffOutRem = pd.merge(traffOutRem, gini, how = 'inner', on = 'country')
print traffOutRem.head()
# Out:
# /Users/petervarshavsky/Documents/Git_NYU/applied_data_science/lab-1/data/
#      country  year  persons_prosecuted  adult_victims  child_victims  \
# 0  Argentina  2005                   0             30              0
# 1  Argentina  2006                   0             63              0
# 2  Argentina  2007                   0             79              0
# 3    Armenia  2003                   0              2              0
# 4    Armenia  2004                   3             33              0
#
#    total_victims           gdp  policy_index  percent_fem_educ  \
# 0             30  2.229076e+11             9          48.82373
# 1             63  2.644897e+11            10          48.77301
# 2             79  3.297615e+11             8          48.79879
# 3              2  2.807061e+09            11          48.50162
# 4             33  3.576615e+09             8          48.34700
#
#    life_expectancy       ...         log_adult_victims  log_child_victims  \
# 0               73       ...                  3.401197                  1
# 1               73       ...                  4.143135                  1
# 2               73       ...                  4.369448                  1
# 3               62       ...                  0.693147                  1
# 4               62       ...                  3.496508                  1
#
#    log_total_victims    log_gdp  log_policy_index  log_percent_fem_educ  \
# 0           3.401197  26.130023          2.197225              3.888216
# 1           4.143135  26.301068          2.302585              3.887177
# 2           4.369448  26.521635          2.079442              3.887706
# 3           0.693147  21.755404          2.397895              3.881597
# 4           3.496508  21.997683          2.079442              3.878404
#
#    log_life_expectancy  penetration  log_penetration   gini
# 0             4.290459     0.761288        -0.272744  0.445
# 1             4.290459     0.756552        -0.278984  0.445
# 2             4.290459     0.743082        -0.296949  0.445
# 3             4.127134     0.578212        -0.547816  0.309
# 4             4.127134     0.591743        -0.524683  0.309
#
# [5 rows x 22 columns]

# %%
traffOutRem['log_gini'] = np.log(traffOutRem.gini)
#print traffOutRem.log_penetration

#print traffOutRem.columns.values.tolist()
y, X = patsy.dmatrices('log_child_victims ~ log_penetration + log_gini + log_life_expectancy + log_percent_fem_educ + year + log_gdp + policy_index', data = traffOutRem, return_type = 'dataframe')
log_fit = sm.OLS(y, X).fit()
print log_fit.summary()

#plt.plot(traffOutRem.log_gini, traffOutRem.log_child_victims, 'ro')
#plt.show
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     7.164
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):           4.84e-07
# Time:                        21:48:36   Log-Likelihood:                -199.87
# No. Observations:                 117   AIC:                             415.7
# Df Residuals:                     109   BIC:                             437.8
# Df Model:                           7
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept             -361.3833    205.814     -1.756      0.082      -769.300    46.533
# log_penetration         -1.7043      0.313     -5.445      0.000        -2.325    -1.084
# log_gini                -0.6482      0.697     -0.930      0.355        -2.030     0.734
# log_life_expectancy      2.6512      1.674      1.584      0.116        -0.666     5.968
# log_percent_fem_educ    -6.7538      8.944     -0.755      0.452       -24.481    10.974
# year                     0.1873      0.102      1.845      0.068        -0.014     0.389
# log_gdp                  0.0236      0.072      0.328      0.743        -0.119     0.166
# policy_index             0.0292      0.064      0.455      0.650        -0.098     0.156
# ==============================================================================
# Omnibus:                       20.147   Durbin-Watson:                   0.738
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.611
# Skew:                           1.096   Prob(JB):                     4.53e-06
# Kurtosis:                       3.493   Cond. No.                     3.23e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.23e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ###### Adding population

# %%
#print filepath
pop_file = "population_by_country.csv"
pop = pd.read_csv(filepath + pop_file, dtype = {'population': np.float64})
pop.head()

traffOutRem = pd.merge(traffOutRem, pop, how = 'inner', on = 'country')
print traffOutRem.head()
# Out:
#      country  year  persons_prosecuted  adult_victims  child_victims  \
# 0  Argentina  2005                   0             30              0
# 1  Argentina  2006                   0             63              0
# 2  Argentina  2007                   0             79              0
# 3    Armenia  2003                   0              2              0
# 4    Armenia  2004                   3             33              0
#
#    total_victims           gdp  policy_index  percent_fem_educ  \
# 0             30  2.229076e+11             9          48.82373
# 1             63  2.644897e+11            10          48.77301
# 2             79  3.297615e+11             8          48.79879
# 3              2  2.807061e+09            11          48.50162
# 4             33  3.576615e+09             8          48.34700
#
#    life_expectancy       ...         log_total_victims    log_gdp  \
# 0               73       ...                  3.401197  26.130023
# 1               73       ...                  4.143135  26.301068
# 2               73       ...                  4.369448  26.521635
# 3               62       ...                  0.693147  21.755404
# 4               62       ...                  3.496508  21.997683
#
#    log_policy_index  log_percent_fem_educ  log_life_expectancy  penetration  \
# 0          2.197225              3.888216             4.290459     0.761288
# 1          2.302585              3.887177             4.290459     0.756552
# 2          2.079442              3.887706             4.290459     0.743082
# 3          2.397895              3.881597             4.127134     0.578212
# 4          2.079442              3.878404             4.127134     0.591743
#
#    log_penetration   gini  log_gini  population
# 0        -0.272744  0.445 -0.809681    42669500
# 1        -0.278984  0.445 -0.809681    42669500
# 2        -0.296949  0.445 -0.809681    42669500
# 3        -0.547816  0.309 -1.174414     3009800
# 4        -0.524683  0.309 -1.174414     3009800
#
# [5 rows x 24 columns]

# %% [markdown]
# ###### Adding population to model

# %%
traffOutRem['log_population'] = np.log(traffOutRem.population)
#print traffOutRem.log_penetration

#print traffOutRem.columns.values.tolist()
y, X = patsy.dmatrices('log_child_victims ~ log_population + log_penetration + log_gini + log_life_expectancy + log_percent_fem_educ + year + log_gdp + policy_index', data = traffOutRem, return_type = 'dataframe')
log_fit = sm.OLS(y, X).fit()
print log_fit.summary()

#plt.plot(traffOutRem.log_gini, traffOutRem.log_child_victims, 'ro')
#plt.show
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log_child_victims   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.275
# Method:                 Least Squares   F-statistic:                     6.495
# Date:                Sun, 12 Oct 2014   Prob (F-statistic):           6.92e-07
# Time:                        21:50:00   Log-Likelihood:                -199.03
# No. Observations:                 117   AIC:                             416.1
# Df Residuals:                     108   BIC:                             440.9
# Df Model:                           8
# ========================================================================================
#                            coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------
# Intercept             -403.0943    207.996     -1.938      0.055      -815.378     9.189
# log_population           0.1860      0.149      1.247      0.215        -0.110     0.481
# log_penetration         -1.6629      0.314     -5.297      0.000        -2.285    -1.041
# log_gini                -0.7680      0.702     -1.094      0.276        -2.160     0.624
# log_life_expectancy      3.1863      1.723      1.849      0.067        -0.230     6.603
# log_percent_fem_educ    -4.2611      9.143     -0.466      0.642       -22.384    13.861
# year                     0.2018      0.102      1.980      0.050        -0.000     0.404
# log_gdp                 -0.0739      0.106     -0.697      0.487        -0.284     0.136
# policy_index             0.0257      0.064      0.401      0.689        -0.101     0.153
# ==============================================================================
# Omnibus:                       20.822   Durbin-Watson:                   0.733
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.505
# Skew:                           1.101   Prob(JB):                     2.89e-06
# Kurtosis:                       3.622   Cond. No.                     3.27e+06
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 3.27e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
