# %%
### Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm

### Settings
# %matplotlib inline
pylab.rcParams['figure.figsize'] = 16, 5  # that's default image size for this interactive session


path = "Bike-Sharing-Dataset/"
file_hour = "hour.csv"

with open (path + file_hour, 'r') as f:
    df_hour = pd.read_csv(f)
    
df_hour
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6c1f67a46c03> in <module>()
#       7 ### Settings
#       8 get_ipython().magic(u'matplotlib inline')
# ----> 9 matplotlib.rcParams.update({'font.size': 18, 'font.family': 'serif'})
#      10
#      11
#
# NameError: name 'matplotlib' is not defined

# %%
plt.scatter(df_hour.hr, df_hour.cnt, c = df_hour.mnth)
plt.show()
